# %% [markdown]
# # Encryption Time Anaylsys

# %%
import matplotlib.pyplot as plt

# Read data from file
with open('encryption_timing_analysis.txt', 'r') as file:
  data = file.readlines()
  data = [float(x.strip()) for x in data]

# Generate X-axis values
x_axis = [i for i in range(28, len(data) + 28)]

# Plot graph
plt.plot(x_axis, data, '-o')
plt.xlabel('Key Size (bits)')
plt.ylabel('Time (s)')
plt.title('RSA Encryption Time Analysis')
plt.show()

# %% [markdown]
# # Decryption Time Analysis

# %%
import matplotlib.pyplot as plt

# Read data from file
with open('decryption_timing_analysis.txt', 'r') as file:
  data = file.readlines()
  data = [float(x.strip()) for x in data]

# Generate X-axis values
x_axis = [i for i in range(28, len(data) + 28)]

# Plot graph
plt.plot(x_axis, data, '-o')
plt.xlabel('Key Size (bits)')
plt.ylabel('Time (s)')
plt.title('RSA Decryption Time Analysis')
plt.show()

# %% [markdown]
# # RSA Bruteforce Attack using Prime Factorization

# %%
import matplotlib.pyplot as plt

# Read data from file
with open('bruteforce_attack_time.txt', 'r') as file:
  data = file.readlines()
  data = [float(x.strip()) for x in data]

# Generate X-axis values
x_axis = [i for i in range(28, len(data) + 28)]

# Plot graph
plt.plot(x_axis, data, '-o')
plt.xlabel('Key Size (bits)')
plt.ylabel('Time (s)')
plt.title('RSA Prime Factorization Attack Timing Analysis')
plt.show()
